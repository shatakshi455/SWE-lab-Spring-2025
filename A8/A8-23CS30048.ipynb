# %% [markdown]
# #QUESTION1

# %% [markdown]
# (a) Create a emp.csv file with the following data
# (b) Create a data frame from this emp.csv file.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('emp.csv')
print(df)
# Out:
#    ID   Name  Gender   Age  Score City
# 0   1  Alice  Female   NaN    9.8   NY
# 1   2    Bob    Male  27.0    6.5   MN
# 2   3    Tom    Male  24.0    NaN   PA
# 3   4  Jerry     NaN  26.0    8.4   PN
# 4   5    Kim  Female   NaN    7.9   NY
# 5   6  Honey     NaN  25.0    NaN   MM
# 6   7   Jisa  Female  21.0    9.0   PA

# %% [markdown]
# (c)Replace ‘Female’ as 0 and ‘Male’ as 1

# %%
df=df.replace('Female', 0)
df=df.replace('Male', 1)
print(df)
# Out:
#    ID   Name  Gender   Age  Score City
# 0   1  Alice     0.0   NaN    9.8   NY
# 1   2    Bob     1.0  27.0    6.5   MN
# 2   3    Tom     1.0  24.0    NaN   PA
# 3   4  Jerry     NaN  26.0    8.4   PN
# 4   5    Kim     0.0   NaN    7.9   NY
# 5   6  Honey     NaN  25.0    NaN   MM
# 6   7   Jisa     0.0  21.0    9.0   PA
# /tmp/ipykernel_5439/3002961749.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace('Male', 1)

# %% [markdown]
# (d)Filling all the missing values in the column ‘Score’ with the average value in that column

# %%
df['Score'] = df['Score'].fillna(df['Score'].mean())
print(df)
# Out:
#    ID   Name  Gender   Age  Score City
# 0   1  Alice     0.0   NaN   9.80   NY
# 1   2    Bob     1.0  27.0   6.50   MN
# 2   3    Tom     1.0  24.0   8.32   PA
# 3   4  Jerry     NaN  26.0   8.40   PN
# 4   5    Kim     0.0   NaN   7.90   NY
# 5   6  Honey     NaN  25.0   8.32   MM
# 6   7   Jisa     0.0  21.0   9.00   PA

# %% [markdown]
# (e)Fill all the missing value in the column ‘Gender’ as 2

# %%
df['Gender'] = df['Gender'].fillna(2)
print(df)
# Out:
#    ID   Name  Gender   Age  Score City
# 0   1  Alice     0.0   NaN   9.80   NY
# 1   2    Bob     1.0  27.0   6.50   MN
# 2   3    Tom     1.0  24.0   8.32   PA
# 3   4  Jerry     2.0  26.0   8.40   PN
# 4   5    Kim     0.0   NaN   7.90   NY
# 5   6  Honey     2.0  25.0   8.32   MM
# 6   7   Jisa     0.0  21.0   9.00   PA

# %% [markdown]
# (f)Change the name of the column ‘Gender’ as ‘Sex’

# %%
df=df.rename(columns={'Gender': 'Sex'})
print(df)
# Out:
#    ID   Name  Sex   Age  Score City
# 0   1  Alice  0.0   NaN   9.80   NY
# 1   2    Bob  1.0  27.0   6.50   MN
# 2   3    Tom  1.0  24.0   8.32   PA
# 3   4  Jerry  2.0  26.0   8.40   PN
# 4   5    Kim  0.0   NaN   7.90   NY
# 5   6  Honey  2.0  25.0   8.32   MM
# 6   7   Jisa  0.0  21.0   9.00   PA

# %% [markdown]
# (g)Arrange the data group by ‘City’

# %%
df = df.sort_values('City')
print(df)
# Out:
#    ID   Name  Sex   Age  Score City
# 5   6  Honey  2.0  25.0   8.32   MM
# 1   2    Bob  1.0  27.0   6.50   MN
# 0   1  Alice  0.0   NaN   9.80   NY
# 4   5    Kim  0.0   NaN   7.90   NY
# 2   3    Tom  1.0  24.0   8.32   PA
# 6   7   Jisa  0.0  21.0   9.00   PA
# 3   4  Jerry  2.0  26.0   8.40   PN

# %% [markdown]
# (h)Add a column, say ‘YOA’ which is initially empty

# %%
df['YOA']=np.nan
print(df)
# Out:
#    ID   Name  Sex   Age  Score City  YOA
# 5   6  Honey  2.0  25.0   8.32   MM  NaN
# 1   2    Bob  1.0  27.0   6.50   MN  NaN
# 0   1  Alice  0.0   NaN   9.80   NY  NaN
# 4   5    Kim  0.0   NaN   7.90   NY  NaN
# 2   3    Tom  1.0  24.0   8.32   PA  NaN
# 6   7   Jisa  0.0  21.0   9.00   PA  NaN
# 3   4  Jerry  2.0  26.0   8.40   PN  NaN

# %% [markdown]
# (i)Fill the values in each row of the column ‘YOA’ with data in the range [2022, 2023, 2024] at
# random.

# %%
df['YOA']=np.random.choice([2022, 2023, 2024], size=len(df))
print(df)
# Out:
#    ID   Name  Sex   Age  Score City   YOA
# 5   6  Honey  2.0  25.0   8.32   MM  2023
# 1   2    Bob  1.0  27.0   6.50   MN  2022
# 0   1  Alice  0.0   NaN   9.80   NY  2022
# 4   5    Kim  0.0   NaN   7.90   NY  2024
# 2   3    Tom  1.0  24.0   8.32   PA  2024
# 6   7   Jisa  0.0  21.0   9.00   PA  2022
# 3   4  Jerry  2.0  26.0   8.40   PN  2022

# %% [markdown]
# (j)Modify all the values in each row of the column ‘Score’ by adding 0.5 to each

# %%
df['Score'] = df['Score'] + 0.5
print(df)
# Out:
#    ID   Name  Sex   Age  Score City   YOA
# 5   6  Honey  2.0  25.0   8.82   MM  2023
# 1   2    Bob  1.0  27.0   7.00   MN  2022
# 0   1  Alice  0.0   NaN  10.30   NY  2022
# 4   5    Kim  0.0   NaN   8.40   NY  2024
# 2   3    Tom  1.0  24.0   8.82   PA  2024
# 6   7   Jisa  0.0  21.0   9.50   PA  2022
# 3   4  Jerry  2.0  26.0   8.90   PN  2022

# %% [markdown]
# (k)Modify a specific entry, say Tom’s age by 28

# %%
df.loc[df['Name']=='Tom', 'Age']=28
print(df)
# Out:
#    ID   Name  Sex   Age  Score City   YOA
# 5   6  Honey  2.0  25.0   8.82   MM  2023
# 1   2    Bob  1.0  27.0   7.00   MN  2022
# 0   1  Alice  0.0   NaN  10.30   NY  2022
# 4   5    Kim  0.0   NaN   8.40   NY  2024
# 2   3    Tom  1.0  28.0   8.82   PA  2024
# 6   7   Jisa  0.0  21.0   9.50   PA  2022
# 3   4  Jerry  2.0  26.0   8.90   PN  2022

# %% [markdown]
# (l)Save the data frame as emp2.csv

# %%
df.to_csv('emp2.csv', index=False)

# %% [markdown]
# #QUESTION2

# %% [markdown]
# (a) Read the .csv file as a Pandas dataframe.

# %%
data = pd.read_csv('breast-cancer.csv')

# %% [markdown]
# (b) Convert all categorical attribute values to numerical values

# %%
data['diagnosis']=data['diagnosis'].replace('M', 0)
data['diagnosis']=data['diagnosis'].replace('B', 1)
# Out:
# /tmp/ipykernel_5439/1891109224.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['diagnosis']=data['diagnosis'].replace('B', 1)

# %% [markdown]
# (c) Remove the column ID from the dataframe

# %%
data = data.drop('id', axis=1)

# %% [markdown]
# (d) Split the dataframe into training and test sets using random sampling and in the ration 2:1.

# %%
from sklearn.model_selection import train_test_split
X=data.drop('diagnosis', axis=1)
y=data['diagnosis']
# Assuming X (features) and y (target) are defined and properly formatted
# Split the dataset into training and testing sets: 67% for training and 33% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# Print the shapes of the train and test data
print("\nTrain and test data shapes:")
print("X_train:", X_train.shape, "X_test:", X_test.shape)
# Out:
# Train and test data shapes:
# X_train: (379, 30) X_test: (190, 30)

# %% [markdown]
# e) Normalize the training and test data using “Standard Scaling”

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# f) Build the classification models using SVM, LR, RF, DT, XGBoost, Gradient Boosting algorithm

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier


# SVM classifier
svm_model = SVC()
svm_model.fit(X_train_scaled, y_train)
y_pred_svm = svm_model.predict(X_test_scaled)
print("SVM done")

# Logistic Regession Classifier
lr_model = LogisticRegression(random_state=42, max_iter=200)
lr_model.fit(X_train_scaled, y_train)
lr_predictions = lr_model.predict(X_test_scaled)
y_pred_lr = lr_predictions
print("LR done")


# Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_scaled, y_train)
rf_predictions = svm_model.predict(X_test_scaled)
y_pred_rf = rf_predictions
print("RF done")


# Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train_scaled, y_train)
dt_predictions = dt_model.predict(X_test_scaled)
y_pred_dt = dt_predictions
print("DT done")


# XGBoost Classifier
xgb_model = XGBClassifier(random_state=42, eval_metric='mlogloss')
xgb_model.fit(X_train_scaled, y_train)
xgb_predictions = xgb_model.predict(X_test_scaled)
y_pred_xgb = xgb_predictions
print("XGB done")

# Gradient Boosting Classifier
gb_model = GradientBoostingClassifier()
gb_model.fit(X_train_scaled, y_train)
gb_predictions = gb_model.predict(X_test_scaled)
y_pred_gb = gb_predictions
print("GB done")
# Out:
# SVM done
# LR done
# RF done
# DT done
# XGB done
# GB done

# %% [markdown]
# (g) Print the Confusion Matrix for each model

# %%
import seaborn as sns
models = {'SVM': SVC(), 
          'Logistic Regression':LogisticRegression(random_state=42, max_iter=200), 
          'Random Forest':RandomForestClassifier(random_state=42), 
          'Decision Tree':DecisionTreeClassifier(random_state=42), 
          'XG Boost':XGBClassifier(random_state=42, eval_metric='mlogloss'), 
          'Gradient Boosting':GradientBoostingClassifier()
         }

results={}
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='magma')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(title)
    plt.show()

for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred=model.predict(X_test_scaled)
    print(f"{name} confusion matrix:\n", confusion_matrix(y_test, y_pred))
    plot_confusion_matrix(y_test, y_pred, f"{name} confusion matrix:\n")
    results[name] = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred)
    }
# Out:
# SVM confusion matrix:
#  [[ 66   2]
#  [  4 118]]
# Logistic Regression confusion matrix:
#  [[ 67   1]
#  [  3 119]]
# Random Forest confusion matrix:
#  [[ 63   5]
#  [  3 119]]
# Decision Tree confusion matrix:
#  [[ 61   7]
#  [  9 113]]
# XG Boost confusion matrix:
#  [[ 62   6]
#  [  3 119]]
# Gradient Boosting confusion matrix:
#  [[ 63   5]
#  [  4 118]]

# %% [markdown]
# (h) Store Accuracy, Precision, Recall and F1 Score for all the models in the form of a table

# %%
results_df=pd.DataFrame.from_dict(results, orient='index')
print(results_df)
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# SVM                  0.968421   0.983333  0.967213  0.975207
# Logistic Regression  0.978947   0.991667  0.975410  0.983471
# Random Forest        0.957895   0.959677  0.975410  0.967480
# Decision Tree        0.915789   0.941667  0.926230  0.933884
# XG Boost             0.952632   0.952000  0.975410  0.963563
# Gradient Boosting    0.952632   0.952000  0.975410  0.963563

# %% [markdown]
# (i) Draw a group bar chart showing the comparison of all the models with respect to each
# performance estimation.

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
x = np.arange(len(models))
w = 0.2

fig, ax = plt.subplots(figsize=(10, 5))

for i, metric in enumerate(metrics):
    values = [results[model][metric] for model in models]
    ax.bar(x+i*w, values, w, label = metric)

ax.set_xlabel('Models')
ax.set_ylabel('Performance')
ax.set_title('Model Performance Comparision')
ax.set_xticks(x+w*1.5)
ax.set_xticklabels(list(models.keys()))
ax.legend()

plt.tight_layout()
plt.show()
